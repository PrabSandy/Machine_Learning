# %%
from random import randint
def selection():
    print("Enter 1 for STONE")
    print("Enter 2 for PAPER")
    print("Enter 3 for SCISSOR")

hn=0
pn=0
print("Welcome to STONE|PAPER|SCISSOR")
print("Enter 1 to start")

c=int(input())   #Input from user 
if(c==1):
    valid=True
    while(True):
        selection()

        Human=int(input("Enter the number from the choices given")) #Input from user Human
        if Human==1:
            print("I choose STONE")
        elif Human==2:
            print("I Choose PAPER")
        elif Human==3:
            print("I choose SCISSOR")
        else:
            print("Choose between 1 2 3. as its a foul the opponent gets a point")

        pc=randint(1,3)
        print(pc)
        

        if((Human==1 and pc==1) or (Human==2 and pc==2) or (Human==3 and pc==3)):
            print("draw")
            print("------------------------------SCORES------------------------------")
            print("User:",hn)
            print("Computer:",pn)
            print("------------------------------------------------------------------")
        elif((Human==1 and pc==3) or (Human==2 and pc==1) or (Human==3 or pc==2)):
            print("Yeah I won")
            hn=hn+1
            print("------------------------------SCORES------------------------------")
            print("User:",hn)
            print("Computer:",pn)
            print("------------------------------------------------------------------")
        else:
            print("The PC won")
            pn=pn+1
            print("------------------------------SCORES------------------------------")
            print("User:",hn)
            print("Computer:",pn)
            print("------------------------------------------------------------------")
        if(pn==5 or hn==5):
            valid=False
            break
        
    if(hn==5):
        print("You won the match, See you next time")
    elif(pn==5):
        print("The Pc won the match, See you next time")

else:
    print("See you next time")
# Out:
# Welcome to STONE|PAPER|SCISSOR
# Enter 1 to start
# 1
# Enter 1 for STONE
# Enter 2 for PAPER
# Enter 3 for SCISSOR
# Enter the number from the choices given1
# I choose STONE
# 3
# Yeah I won
# ------------------------------SCORES------------------------------
# User: 1
# Computer: 0
# ------------------------------------------------------------------
# Enter 1 for STONE
# Enter 2 for PAPER
# Enter 3 for SCISSOR
# Enter the number from the choices given2
# I Choose PAPER
# 3
# The PC won
# ------------------------------SCORES------------------------------
# User: 1
# Computer: 1
# ------------------------------------------------------------------
# Enter 1 for STONE
# Enter 2 for PAPER
# Enter 3 for SCISSOR
# Enter the number from the choices given3
# I choose SCISSOR
# 3
# draw
# ------------------------------SCORES------------------------------
# User: 1
# Computer: 1
# ------------------------------------------------------------------
# Enter 1 for STONE
# Enter 2 for PAPER
# Enter 3 for SCISSOR
# Enter the number from the choices given3
# I choose SCISSOR
# 1
# Yeah I won
# ------------------------------SCORES------------------------------
# User: 2
# Computer: 1
# ------------------------------------------------------------------
# Enter 1 for STONE
# Enter 2 for PAPER
# Enter 3 for SCISSOR
# Enter the number from the choices given4
# Choose between 1 2 3. as its a foul the opponent gets a point
# 1
# The PC won
# ------------------------------SCORES------------------------------
# User: 2
# Computer: 2
# ------------------------------------------------------------------
# Enter 1 for STONE
# Enter 2 for PAPER
# Enter 3 for SCISSOR
# Enter the number from the choices given5
# Choose between 1 2 3. as its a foul the opponent gets a point
# 3
# The PC won
# ------------------------------SCORES------------------------------
# User: 2
# Computer: 3
# ------------------------------------------------------------------
# Enter 1 for STONE
# Enter 2 for PAPER
# Enter 3 for SCISSOR
# Enter the number from the choices given7
# Choose between 1 2 3. as its a foul the opponent gets a point
# 2
# Yeah I won
# ------------------------------SCORES------------------------------
# User: 3
# Computer: 3
# ------------------------------------------------------------------
# Enter 1 for STONE
# Enter 2 for PAPER
# Enter 3 for SCISSOR
# Enter the number from the choices given8
# Choose between 1 2 3. as its a foul the opponent gets a point
# 1
# The PC won
# ------------------------------SCORES------------------------------
# User: 3
# Computer: 4
# ------------------------------------------------------------------
# Enter 1 for STONE
# Enter 2 for PAPER
# Enter 3 for SCISSOR
# Enter the number from the choices given4
# Choose between 1 2 3. as its a foul the opponent gets a point
# 1
# The PC won
# ------------------------------SCORES------------------------------
# User: 3
# Computer: 5
# ------------------------------------------------------------------
# The Pc won the match, See you next time
